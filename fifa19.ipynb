# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
fifa=pd.read_csv('data.csv')

# %%
fifa.head()
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           1  158023           L. Messi   31
# 1           2   20801  Cristiano Ronaldo   33
# 2           3  190871          Neymar Jr   26
# 3           4  193080             De Gea   27
# 4           5  192985       K. De Bruyne   27
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
#
#                                   Flag  Overall  Potential  \
# 0  https://cdn.sofifa.org/flags/52.png       94         94
# 1  https://cdn.sofifa.org/flags/38.png       94         94
# 2  https://cdn.sofifa.org/flags/54.png       92         93
# 3  https://cdn.sofifa.org/flags/45.png       91         93
# ...

# %%
fifa.shape
# Out:
# (16643, 89)

# %%
# Top 10 countries having large number of players.
Playercount = fifa['Nationality'].value_counts()[0:10]
Playercount
# Out:
# England        1475
# Germany        1151
# Spain           974
# France          853
# Argentina       833
# Brazil          788
# Italy           579
# Colombia        570
# Japan           455
# Netherlands     426
# Name: Nationality, dtype: int64

# %%
Country = fifa['Nationality'].value_counts()[0:10].keys()
Country
# Out:
# Index(['England', 'Germany', 'Spain', 'France', 'Argentina', 'Brazil', 'Italy',
#        'Colombia', 'Japan', 'Netherlands'],
#       dtype='object')

# %% [markdown]
# Top 10 countries having large number of players.

# %%
plt.bar(Country,Playercount,color ="#00ff55")
plt.grid(linestyle =':')
plt.rcParams["figure.figsize"] = (10,5)
plt.show()

# %% [markdown]
# Conclusion :
# 1. England is the country having total 1662 football players which is highest in world.
# 2. Germany is the 2nd largest country having 1198 football players followed by England.
# 3. Spain ranks 3rd with 1072 football players.

# %% [markdown]
# Top 10 highest earnig football players.

# %%
Earning = fifa[['Name','Wage']]

# %%
Earning.head()
# Out:
#                 Name    Wage
# 0           L. Messi  565000
# 1  Cristiano Ronaldo  405000
# 2          Neymar Jr  290000
# 3             De Gea  260000
# 4       K. De Bruyne  355000

# %%
Earning = Earning.sort_values(by=['Wage'],ascending=False)

# %%
Earning.head(10)
# Out:
#                  Name    Wage
# 0            L. Messi  565000
# 7           L. Suárez  455000
# 6           L. Modrić  420000
# 1   Cristiano Ronaldo  405000
# 8        Sergio Ramos  380000
# 11           T. Kroos  355000
# 35            G. Bale  355000
# 4        K. De Bruyne  355000
# 5           E. Hazard  340000
# 31           Coutinho  340000

# %%
plt.bar(list(Earning['Name'])[0:10],list(Earning['Wage'])[0:10],color="#00ff55")
plt.grid(linestyle=':')
plt.show()

# %%
England=fifa[fifa['Nationality']=='England']

# %%
England.head()
# Out:
#      Unnamed: 0      ID         Name  Age  \
# 16           17  202126      H. Kane   24
# 58           59  202652  R. Sterling   23
# 114         115  211117      D. Alli   22
# 132         133  188377    K. Walker   28
# 175         176  204935  J. Pickford   24
#
#                                               Photo Nationality  \
# 16   https://cdn.sofifa.org/players/4/19/202126.png     England
# 58   https://cdn.sofifa.org/players/4/19/202652.png     England
# 114  https://cdn.sofifa.org/players/4/19/211117.png     England
# 132  https://cdn.sofifa.org/players/4/19/188377.png     England
# 175  https://cdn.sofifa.org/players/4/19/204935.png     England
#
#                                     Flag  Overall  Potential  \
# 16   https://cdn.sofifa.org/flags/14.png       89         91
# 58   https://cdn.sofifa.org/flags/14.png       86         89
# 114  https://cdn.sofifa.org/flags/14.png       84         90
# 132  https://cdn.sofifa.org/flags/14.png       84         84
# ...

# %%
England.sort_values(by=['Overall']).head(10)
# Out:
#        Unnamed: 0      ID                  Name  Age  \
# 16642       16643  246269             G. Nugent   16
# 16626       16627  245569            L. Watkins   18
# 16627       16628  245570  J. Norville-Williams   18
# 16628       16629  245571             S. Squire   18
# 16641       16642  246268        D. Walker-Rice   17
# 16638       16639  238813          J. Lundstram   19
# 16640       16641  241638             B. Worman   16
# 16634       16635  242844            J. Livesey   18
# 16591       16592  243204            M. Roberts   17
# 16593       16594  245533             J. Devine   18
#
#                                                 Photo Nationality  \
# 16642  https://cdn.sofifa.org/players/4/19/246269.png     England
# 16626  https://cdn.sofifa.org/players/4/19/245569.png     England
# 16627  https://cdn.sofifa.org/players/4/19/245570.png     England
# 16628  https://cdn.sofifa.org/players/4/19/245571.png     England
# ...

# %%
# Top 10 players from England.
England[['Name','Overall','Potential']].sort_values(by=['Overall'],ascending=False).head(10)
# Out:
#              Name  Overall  Potential
# 16        H. Kane       89         91
# 58    R. Sterling       86         89
# 114       D. Alli       84         90
# 132     K. Walker       84         84
# 175   J. Pickford       83         88
# 177     J. Stones       83         87
# 254    H. Maguire       82         85
# 285   K. Trippier       82         82
# 291  J. Henderson       82         82
# 249    J. Lingard       82         83

# %%
# Top earning player's and their football club
fifa[['Name','Nationality','Club','Wage']].sort_values(by=['Wage'],ascending=False).head(10)
# Out:
#                  Name Nationality             Club    Wage
# 0            L. Messi   Argentina     FC Barcelona  565000
# 7           L. Suárez     Uruguay     FC Barcelona  455000
# 6           L. Modrić     Croatia      Real Madrid  420000
# 1   Cristiano Ronaldo    Portugal         Juventus  405000
# 8        Sergio Ramos       Spain      Real Madrid  380000
# 11           T. Kroos     Germany      Real Madrid  355000
# 35            G. Bale       Wales      Real Madrid  355000
# 4        K. De Bruyne     Belgium  Manchester City  355000
# 5           E. Hazard     Belgium          Chelsea  340000
# 31           Coutinho      Brazil     FC Barcelona  340000

# %%
#Player's overall performance with respect to their price.
PL=fifa[['Name','Overall','Wage']].sort_values(by=['Wage'],ascending=False).head(10)

# %%
PL
# Out:
#                  Name  Overall    Wage
# 0            L. Messi       94  565000
# 7           L. Suárez       91  455000
# 6           L. Modrić       91  420000
# 1   Cristiano Ronaldo       94  405000
# 8        Sergio Ramos       91  380000
# 11           T. Kroos       90  355000
# 35            G. Bale       88  355000
# 4        K. De Bruyne       91  355000
# 5           E. Hazard       91  340000
# 31           Coutinho       88  340000

# %%
#plt.bar(list(Earning['Name'])[0:10],list(Earning['Wage'])[0:10],color="#00ff55")

plt.bar(list(PL['Name'])[0:10],list(PL['Wage'])[0:10],color='#00ff55')
plt.grid(linestyle=':')
